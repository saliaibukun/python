# %%
import pandas as pd

# %%
data = {
    'city': ['new york','london','new york','paris','london','berlin','paris','paris'],
    'gender': ['male','female','female','male','female','male','female','male']
}

df = pd.DataFrame(data)
df
# Out:
#        city  gender
# 0  new york    male
# 1    london  female
# 2  new york  female
# 3     paris    male
# 4    london  female
# 5    berlin    male
# 6     paris  female
# 7     paris    male

# %%
df['city'].value_counts()
# Out:
# city
# paris       3
# new york    2
# london      2
# berlin      1
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# male      4
# female    4
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=type)
# Out:
# gender
# male      0.5
# female    0.5
# Name: proportion, dtype: float64

# %%
df['city'].unique()
# Out:
# array(['new york', 'london', 'paris', 'berlin'], dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['city'].nunique()
# Out:
# 4

# %%
df['gender'].nunique()
# Out:
# 2
