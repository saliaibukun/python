# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('MOCK_DATA.csv')

# %%
print(df.head)
print(df.info)
print(df.describe)
# Out:
# <bound method NDFrame.head of        id first_name    last_name                           email  \
# 0       1       Oran         Kurt                okurt0@diigo.com
# 1       2    Cherice     Stoggles        cstoggles1@rakuten.co.jp
# 2       3   Phillipp       Adlard                 padlard2@ca.gov
# 3       4      Maria       Rosita         mrosita3@deviantart.com
# 4       5    Romonda      Luckett          rluckett4@columbia.edu
# ..    ...        ...          ...                             ...
# 995   996       Hans  Kislingbury  hkislingburyrn@fastcompany.com
# 996   997  Alejandro     Lehrmann           alehrmannro@google.cn
# 997   998     Portie         Bane                  pbanerp@vk.com
# 998   999   Christye      Verrall           cverrallrq@forbes.com
# 999  1000      Shawn       Ahrend         sahrendrr@bigcartel.com
#
#           gender       ip_address
# 0           Male     22.44.205.45
# 1         Female  141.181.131.239
# 2           Male  224.125.201.185
# 3    Genderfluid  117.252.116.183
# 4         Female    105.60.175.13
# ..           ...              ...
# 995         Male   96.136.110.110
# 996         Male    0.213.157.229
# 997         Male  190.228.124.114
# 998       Female      96.3.117.64
# 999       Female     200.41.253.9
#
# [1000 rows x 6 columns]>
# <bound method DataFrame.info of        id first_name    last_name                           email  \
# 0       1       Oran         Kurt                okurt0@diigo.com
# 1       2    Cherice     Stoggles        cstoggles1@rakuten.co.jp
# 2       3   Phillipp       Adlard                 padlard2@ca.gov
# 3       4      Maria       Rosita         mrosita3@deviantart.com
# 4       5    Romonda      Luckett          rluckett4@columbia.edu
# ..    ...        ...          ...                             ...
# 995   996       Hans  Kislingbury  hkislingburyrn@fastcompany.com
# 996   997  Alejandro     Lehrmann           alehrmannro@google.cn
# 997   998     Portie         Bane                  pbanerp@vk.com
# 998   999   Christye      Verrall           cverrallrq@forbes.com
# 999  1000      Shawn       Ahrend         sahrendrr@bigcartel.com
#
#           gender       ip_address
# 0           Male     22.44.205.45
# 1         Female  141.181.131.239
# 2           Male  224.125.201.185
# 3    Genderfluid  117.252.116.183
# 4         Female    105.60.175.13
# ..           ...              ...
# 995         Male   96.136.110.110
# 996         Male    0.213.157.229
# 997         Male  190.228.124.114
# 998       Female      96.3.117.64
# 999       Female     200.41.253.9
#
# [1000 rows x 6 columns]>
# <bound method NDFrame.describe of        id first_name    last_name                           email  \
# 0       1       Oran         Kurt                okurt0@diigo.com
# 1       2    Cherice     Stoggles        cstoggles1@rakuten.co.jp
# 2       3   Phillipp       Adlard                 padlard2@ca.gov
# 3       4      Maria       Rosita         mrosita3@deviantart.com
# 4       5    Romonda      Luckett          rluckett4@columbia.edu
# ..    ...        ...          ...                             ...
# 995   996       Hans  Kislingbury  hkislingburyrn@fastcompany.com
# 996   997  Alejandro     Lehrmann           alehrmannro@google.cn
# 997   998     Portie         Bane                  pbanerp@vk.com
# 998   999   Christye      Verrall           cverrallrq@forbes.com
# 999  1000      Shawn       Ahrend         sahrendrr@bigcartel.com
#
#           gender       ip_address
# 0           Male     22.44.205.45
# 1         Female  141.181.131.239
# 2           Male  224.125.201.185
# 3    Genderfluid  117.252.116.183
# 4         Female    105.60.175.13
# ..           ...              ...
# 995         Male   96.136.110.110
# 996         Male    0.213.157.229
# 997         Male  190.228.124.114
# 998       Female      96.3.117.64
# 999       Female     200.41.253.9
#
# [1000 rows x 6 columns]>

# %%
sns.histplot(df['gender'], kde=True)
plt.title('distribution of gender')
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')

plt.figure(figsize=(11,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('correlation between features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 numeric_df = df.select_dtypes(Include='number')
#       3 plt.Figure(figsize=(110,6))
#       4 sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm')
#
# TypeError: DataFrame.select_dtypes() got an unexpected keyword argument 'Include'. Did you mean 'include'?
