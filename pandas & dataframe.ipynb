# %%
import pandas as pd

# %%
df = pd.read_csv('MOCK_DATA.csv')

# %%
df.head()
# Out:
#    id first_name last_name                     email       gender  \
# 0   1       Oran      Kurt          okurt0@diigo.com         Male
# 1   2    Cherice  Stoggles  cstoggles1@rakuten.co.jp       Female
# 2   3   Phillipp    Adlard           padlard2@ca.gov         Male
# 3   4      Maria    Rosita   mrosita3@deviantart.com  Genderfluid
# 4   5    Romonda   Luckett    rluckett4@columbia.edu       Female
#
#         ip_address
# 0     22.44.205.45
# 1  141.181.131.239
# 2  224.125.201.185
# 3  117.252.116.183
# 4    105.60.175.13

# %%
df = pd.read_csv('MOCK_DATA.csv', encoding='utf-8')

# %%
df = pd.read_csv('MOCK_DATA.csv')

# %%
df.head()
# Out:
#    id first_name last_name                     email       gender  \
# 0   1       Oran      Kurt          okurt0@diigo.com         Male
# 1   2    Cherice  Stoggles  cstoggles1@rakuten.co.jp       Female
# 2   3   Phillipp    Adlard           padlard2@ca.gov         Male
# 3   4      Maria    Rosita   mrosita3@deviantart.com  Genderfluid
# 4   5    Romonda   Luckett    rluckett4@columbia.edu       Female
#
#         ip_address
# 0     22.44.205.45
# 1  141.181.131.239
# 2  224.125.201.185
# 3  117.252.116.183
# 4    105.60.175.13

# %%
df.tail()
# Out:
#        id first_name    last_name                           email  gender  \
# 995   996       Hans  Kislingbury  hkislingburyrn@fastcompany.com    Male
# 996   997  Alejandro     Lehrmann           alehrmannro@google.cn    Male
# 997   998     Portie         Bane                  pbanerp@vk.com    Male
# 998   999   Christye      Verrall           cverrallrq@forbes.com  Female
# 999  1000      Shawn       Ahrend         sahrendrr@bigcartel.com  Female
#
#           ip_address
# 995   96.136.110.110
# 996    0.213.157.229
# 997  190.228.124.114
# 998      96.3.117.64
# 999     200.41.253.9

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
df.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df['email']
# Out:
# 0                    okurt0@diigo.com
# 1            cstoggles1@rakuten.co.jp
# 2                     padlard2@ca.gov
# 3             mrosita3@deviantart.com
# 4              rluckett4@columbia.edu
#                     ...
# 995    hkislingburyrn@fastcompany.com
# 996             alehrmannro@google.cn
# 997                    pbanerp@vk.com
# 998             cverrallrq@forbes.com
# 999           sahrendrr@bigcartel.com
# Name: email, Length: 1000, dtype: object

# %%
df[['last_name', 'gender','first_name', 'email']]
# Out:
#        last_name       gender first_name                           email
# 0           Kurt         Male       Oran                okurt0@diigo.com
# 1       Stoggles       Female    Cherice        cstoggles1@rakuten.co.jp
# 2         Adlard         Male   Phillipp                 padlard2@ca.gov
# 3         Rosita  Genderfluid      Maria         mrosita3@deviantart.com
# 4        Luckett       Female    Romonda          rluckett4@columbia.edu
# ..           ...          ...        ...                             ...
# 995  Kislingbury         Male       Hans  hkislingburyrn@fastcompany.com
# 996     Lehrmann         Male  Alejandro           alehrmannro@google.cn
# 997         Bane         Male     Portie                  pbanerp@vk.com
# 998      Verrall       Female   Christye           cverrallrq@forbes.com
# 999       Ahrend       Female      Shawn         sahrendrr@bigcartel.com
#
# [1000 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# id                           1
# first_name                Oran
# last_name                 Kurt
# email         okurt0@diigo.com
# gender                    Male
# ip_address        22.44.205.45
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# id                           1
# first_name                Oran
# last_name                 Kurt
# email         okurt0@diigo.com
# gender                    Male
# ip_address        22.44.205.45
# Name: 0, dtype: object

# %%
df[df['id'] > 900]
# Out:
#        id  first_name    last_name                           email  gender  \
# 900   901      Domini       Drewet             ddrewetp0@prlog.org  Female
# 901   902      Ruddie       Perris             rperrisp1@google.es    Male
# 902   903      Stacee      Simmell          ssimmellp2@reuters.com    Male
# 903   904  Christophe   Plumridege    cplumridegep3@shareasale.com    Male
# 904   905      Lorena      Hullyer    lhullyerp4@blogtalkradio.com  Female
# ..    ...         ...          ...                             ...     ...
# 995   996        Hans  Kislingbury  hkislingburyrn@fastcompany.com    Male
# 996   997   Alejandro     Lehrmann           alehrmannro@google.cn    Male
# 997   998      Portie         Bane                  pbanerp@vk.com    Male
# 998   999    Christye      Verrall           cverrallrq@forbes.com  Female
# 999  1000       Shawn       Ahrend         sahrendrr@bigcartel.com  Female
#
#           ip_address
# 900   175.206.24.103
# 901   72.117.198.235
# 902    97.167.20.158
# 903      197.4.89.97
# 904   127.137.16.147
# ..               ...
# 995   96.136.110.110
# 996    0.213.157.229
# 997  190.228.124.114
# 998      96.3.117.64
# 999     200.41.253.9
#
# [100 rows x 6 columns]

# %%
df['id'].max()
# Out:
# 1000

# %%
df[(df['id'] > 900) & (df['gender'] == 'Female')]
# Out:
#        id  first_name      last_name                           email  gender  \
# 900   901      Domini         Drewet             ddrewetp0@prlog.org  Female
# 904   905      Lorena        Hullyer    lhullyerp4@blogtalkradio.com  Female
# 908   909     Lurlene         Girsch              lgirschp8@usda.gov  Female
# 911   912     Rosanna      Ferbrache           rferbrachepb@ehow.com  Female
# 914   915      Debbie          Akast            dakastpe@twitter.com  Female
# 915   916       Aubry        Forshaw            aforshawpf@google.it  Female
# 918   919  Vilhelmina      MacEveley         vmaceveleypi@seesaa.net  Female
# 919   920    Laurette         Minger         lmingerpj@hostgator.com  Female
# 928  134.122.129.118
# 929  199.122.107.216
# 930  100.217.132.220
# 931      25.88.84.43
# 932   47.156.120.128
# 933  223.169.166.148
# 935    37.94.140.197
# 940   41.153.127.234
# 941   215.171.31.235
# 942    132.21.243.54
# 945    254.152.222.7
# 946   122.115.152.59
# 947   101.102.139.78
# 948   202.243.141.65
# 949      6.151.52.27
# 952      39.98.35.84
# 953     89.71.31.120
# 955     40.161.72.65
# 959   140.177.17.159
# 963     26.220.8.242
# 968   240.68.198.241
# 969   254.88.106.100
# 973     95.17.181.15
# 978   178.245.118.95
# 980   220.30.134.225
# 981   64.173.165.181
# 983  125.107.232.232
# 984   152.181.46.157
# 989    244.30.249.59
# 994   178.152.60.148
# 998      96.3.117.64
# 999     200.41.253.9

# %%
df['newcol'] = df['id'] + 2

# %%
df['id'] = df['id'] * 2

# %%
df.drop('first_name',axis=1, inplace=True)

# %%
df.drop(0, axis=0, inplace=True)

# %%
df = pd.read_csv('MOCK_DATA.csv')

# %%
df.head()
# Out:
#    id first_name last_name                     email       gender  \
# 0   1       Oran      Kurt          okurt0@diigo.com         Male
# 1   2    Cherice  Stoggles  cstoggles1@rakuten.co.jp       Female
# 2   3   Phillipp    Adlard           padlard2@ca.gov         Male
# 3   4      Maria    Rosita   mrosita3@deviantart.com  Genderfluid
# 4   5    Romonda   Luckett    rluckett4@columbia.edu       Female
#
#         ip_address
# 0     22.44.205.45
# 1  141.181.131.239
# 2  224.125.201.185
# 3  117.252.116.183
# 4    105.60.175.13

# %%
df.sort_values('gender', ascending=True)
# Out:
#       id  first_name last_name                           email      gender  \
# 923  924     Bertina    Galvan          bgalvanpn@yolasite.com     Agender
# 130  131       Kerby   Pessler     kpessler3m@businesswire.com     Agender
# 157  158  Sigismondo  Rookesby     srookesby4d@squarespace.com     Agender
# 638  639       Lonni    Neenan   lneenanhq@businessinsider.com     Agender
# 172  173      Dorrie    Pagram             dpagram4s@tmall.com     Agender
# ..   ...         ...       ...                             ...         ...
# 503  504       Nadia    Ceeley  nceeleydz@pagesperso-orange.fr  Polygender
# 98    99       Kasey  Rickhuss    krickhuss2q@businessweek.com  Polygender
# 639  640     Kristin    Ruston           krustonhr@histats.com  Polygender
# 917  918      Aldous   Golston            agolstonph@webmd.com  Polygender
# 111  112      Terrye      Hare                 thare33@mit.edu  Polygender
#
#           ip_address
# 923   98.174.103.246
# 130   201.124.20.237
# 157    26.13.231.164
# 638     125.71.6.230
# 172  141.175.135.197
# ..               ...
# 503   102.105.56.108
# 98    228.198.195.48
# 639   231.58.228.251
# 917   139.250.118.18
# 111     11.58.50.154
#
# [1000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# id            0
# first_name    0
# last_name     0
# email         0
# gender        0
# ip_address    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.fillna(0,inplace=True)

# %%
df.to_csv('output.csv', index=False)
